# %% [markdown]
# ### Exercise Instructions from Lesson ipynb file
# ***The end result of this exercise should be a file named acquire.py.***
# 1. Using the code from the lesson as a guide and the REST API from https://python.zgulde.net/api/v1/items as we did in the lesson, create a dataframe named items that has all of the data for items.
#
# 2. Do the same thing, but for stores (https://python.zgulde.net/api/v1/stores)
#
# 3. Extract the data for sales (https://python.zgulde.net/api/v1/sales). There are a lot of pages of data here, so your code will need to be a little more complex. Your code should continue fetching data from the next page until all of the data is extracted.
#
# 4. Save the data in your files to local csv files so that it will be faster to access in the future.
#
# 5. Combine the data from your three separate dataframes into one large dataframe.
#
# 6. Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv
#
# 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.

# %%
import requests
import pandas as pd

# %% [markdown]
# 1. First Step

# %%
domain = ' https://python.zgulde.net/'
endpoint = 'api/v1/items'
items_list = []

url = domain + endpoint
response = requests.get(url)
data = response.json()

items_list.extend(data['payload']['items'])

for page in range(data['payload']['max_page']-1):
    url = domain + data['payload']['next_page']
    response = requests.get(url)
    data = response.json()
    
    items_list.extend(data['payload']['items'])

items = pd.DataFrame(items_list)

print("Shape of items dataframe ", items.shape)
items.head(10)
# Out:
# Shape of items dataframe  (50, 6)
#            item_brand  item_id  \
# 0            Riceland        1
# 1              Caress        2
# 2         Earths Best        3
# 3          Boars Head        4
# 4      Back To Nature        5
# 5        Sally Hansen        6
# 6  Twinings Of London        7
# 7       Lea & Perrins        8
# 8        Van De Kamps        9
# 9               Ahold       10
#
#                                            item_name  item_price  \
# 0                     Riceland American Jazmine Rice        0.84
# 1  Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2  Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 3   Boars Head Sliced White American Cheese - 120 Ct        3.14
# 4  Back To Nature Gluten Free White Cheddar Rice ...        2.61
# 5  Sally Hansen Nail Color Magnetic 903 Silver El...        6.93
# 6  Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 7  Lea & Perrins Marinade In-a-bag Cracked Pepper...        1.68
# 8         Van De Kamps Fillets Beer Battered - 10 Ct        1.79
# 9                                Ahold Cocoa Almonds        3.17
#
#      item_upc12    item_upc14
# 0   35200264013   35200264013
# 1   11111065925   11111065925
# 2   23923330139   23923330139
# 3  208528800007  208528800007
# 4  759283100036  759283100036
# 5   74170388732   74170388732
# 6   70177154004   70177154004
# 7   51600080015   51600080015
# 8   19600923015   19600923015
# 9  688267141676  688267141676

# %% [markdown]
# 2. Do the same thing, but for stores (https://python.zgulde.net/api/v1/stores)

# %%
domain = ' https://python.zgulde.net/'
endpoint = 'api/v1/stores'
stores_list = []

url = domain + endpoint
response = requests.get(url)
data = response.json()

stores_list.extend(data['payload']['stores'])

for page in range(data['payload']['max_page']-1):
    url = domain + data['payload']['next_page']
    response = requests.get(url)
    data = response.json()
    
    stores_list.extend(data['payload']['stores'])

stores = pd.DataFrame(stores_list)

print("Shape of items dataframe ", stores.shape)
stores.head(10)
# Out:
# Shape of items dataframe  (10, 5)
#              store_address   store_city  store_id store_state store_zipcode
# 0   12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 1         9255 FM 471 West  San Antonio         2          TX         78251
# 2  2118 Fredericksburg Rdj  San Antonio         3          TX         78201
# 3          516 S Flores St  San Antonio         4          TX         78204
# 4          1520 Austin Hwy  San Antonio         5          TX         78218
# 5       1015 S WW White Rd  San Antonio         6          TX         78220
# 6   12018 Perrin Beitel Rd  San Antonio         7          TX         78217
# 7      15000 San Pedro Ave  San Antonio         8          TX         78232
# 8       735 SW Military Dr  San Antonio         9          TX         78221
# 9     8503 NW Military Hwy  San Antonio        10          TX         78231

# %% [markdown]
# 3. Extract the data for sales (https://python.zgulde.net/api/v1/sales). There are a lot of pages of data here, so your code will need to be a little more complex. Your code should continue fetching data from the next page until all of the data is extracted.

# %%
domain = 'https://python.zgulde.net/'
endpoint = 'api/v1/sales'
sales_list = []

url = domain + endpoint
response = requests.get(url)
data = response.json()

# Get initial data from page 1
sales_list.extend(data['payload']['sales'])

for page in range(data['payload']['max_page']-1):
    print("Checking page: " , page, "of ", data['payload']['max_page'])
    
    url = domain + data['payload']['next_page']
    response = requests.get(url)
    print("Downloading ", url)
    data = response.json()
    print(len(data['payload']['sales']), "Number of Records for this page")
    
    sales_list.extend(data['payload']['sales'])
    
    print("Records saved: ", len(sales_list))

sales = pd.DataFrame(sales_list)

print("Shape of sales df: ",sales.shape)
sales.head()
# Out:
# Checking page:  0 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=2
# 5000 Number of Records for this page
# Records saved:  10000
# Checking page:  1 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=3
# 5000 Number of Records for this page
# Records saved:  15000
# Checking page:  2 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=4
# 5000 Number of Records for this page
# Records saved:  20000
# Checking page:  3 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=5
# 5000 Number of Records for this page
# Records saved:  25000
# Checking page:  4 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=6
# 5000 Number of Records for this page
# Records saved:  30000
# Checking page:  5 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=7
# 5000 Number of Records for this page
# Records saved:  35000
# Checking page:  6 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=8
# 5000 Number of Records for this page
# Records saved:  40000
# Checking page:  7 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=9
# 5000 Number of Records for this page
# Records saved:  45000
# Checking page:  8 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=10
# 5000 Number of Records for this page
# Records saved:  50000
# Checking page:  9 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=11
# 5000 Number of Records for this page
# Records saved:  55000
# Checking page:  10 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=12
# 5000 Number of Records for this page
# Records saved:  60000
# Checking page:  11 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=13
# 5000 Number of Records for this page
# Records saved:  65000
# Checking page:  12 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=14
# 5000 Number of Records for this page
# Records saved:  70000
# Checking page:  13 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=15
# 5000 Number of Records for this page
# Records saved:  75000
# Checking page:  14 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=16
# 5000 Number of Records for this page
# Records saved:  80000
# Checking page:  15 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=17
# 5000 Number of Records for this page
# Records saved:  85000
# Checking page:  16 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=18
# 5000 Number of Records for this page
# Records saved:  90000
# Checking page:  17 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=19
# 5000 Number of Records for this page
# Records saved:  95000
# Checking page:  18 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=20
# 5000 Number of Records for this page
# Records saved:  100000
# Checking page:  19 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=21
# 5000 Number of Records for this page
# Records saved:  105000
# Checking page:  20 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=22
# 5000 Number of Records for this page
# Records saved:  110000
# Checking page:  21 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=23
# 5000 Number of Records for this page
# Records saved:  115000
# Checking page:  22 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=24
# 5000 Number of Records for this page
# Records saved:  120000
# Checking page:  23 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=25
# 5000 Number of Records for this page
# Records saved:  125000
# Checking page:  24 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=26
# 5000 Number of Records for this page
# Records saved:  130000
# Checking page:  25 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=27
# 5000 Number of Records for this page
# Records saved:  135000
# Checking page:  26 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=28
# 5000 Number of Records for this page
# Records saved:  140000
# Checking page:  27 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=29
# 5000 Number of Records for this page
# Records saved:  145000
# Checking page:  28 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=30
# 5000 Number of Records for this page
# Records saved:  150000
# Checking page:  29 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=31
# 5000 Number of Records for this page
# Records saved:  155000
# Checking page:  30 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=32
# 5000 Number of Records for this page
# Records saved:  160000
# Checking page:  31 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=33
# 5000 Number of Records for this page
# Records saved:  165000
# Checking page:  32 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=34
# 5000 Number of Records for this page
# Records saved:  170000
# Checking page:  33 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=35
# 5000 Number of Records for this page
# Records saved:  175000
# Checking page:  34 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=36
# 5000 Number of Records for this page
# Records saved:  180000
# Checking page:  35 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=37
# 5000 Number of Records for this page
# Records saved:  185000
# Checking page:  36 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=38
# 5000 Number of Records for this page
# Records saved:  190000
# Checking page:  37 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=39
# 5000 Number of Records for this page
# Records saved:  195000
# Checking page:  38 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=40
# 5000 Number of Records for this page
# Records saved:  200000
# Checking page:  39 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=41
# 5000 Number of Records for this page
# Records saved:  205000
# Checking page:  40 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=42
# 5000 Number of Records for this page
# Records saved:  210000
# Checking page:  41 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=43
# 5000 Number of Records for this page
# Records saved:  215000
# Checking page:  42 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=44
# 5000 Number of Records for this page
# Records saved:  220000
# Checking page:  43 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=45
# 5000 Number of Records for this page
# Records saved:  225000
# Checking page:  44 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=46
# 5000 Number of Records for this page
# Records saved:  230000
# Checking page:  45 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=47
# 5000 Number of Records for this page
# Records saved:  235000
# Checking page:  46 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=48
# 5000 Number of Records for this page
# Records saved:  240000
# Checking page:  47 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=49
# 5000 Number of Records for this page
# Records saved:  245000
# Checking page:  48 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=50
# 5000 Number of Records for this page
# Records saved:  250000
# Checking page:  49 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=51
# 5000 Number of Records for this page
# Records saved:  255000
# Checking page:  50 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=52
# 5000 Number of Records for this page
# Records saved:  260000
# Checking page:  51 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=53
# 5000 Number of Records for this page
# Records saved:  265000
# Checking page:  52 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=54
# 5000 Number of Records for this page
# Records saved:  270000
# Checking page:  53 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=55
# 5000 Number of Records for this page
# Records saved:  275000
# Checking page:  54 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=56
# 5000 Number of Records for this page
# Records saved:  280000
# Checking page:  55 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=57
# 5000 Number of Records for this page
# Records saved:  285000
# Checking page:  56 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=58
# 5000 Number of Records for this page
# Records saved:  290000
# Checking page:  57 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=59
# 5000 Number of Records for this page
# Records saved:  295000
# Checking page:  58 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=60
# 5000 Number of Records for this page
# Records saved:  300000
# Checking page:  59 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=61
# 5000 Number of Records for this page
# Records saved:  305000
# Checking page:  60 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=62
# 5000 Number of Records for this page
# Records saved:  310000
# Checking page:  61 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=63
# 5000 Number of Records for this page
# Records saved:  315000
# Checking page:  62 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=64
# 5000 Number of Records for this page
# Records saved:  320000
# Checking page:  63 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=65
# 5000 Number of Records for this page
# Records saved:  325000
# Checking page:  64 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=66
# 5000 Number of Records for this page
# Records saved:  330000
# Checking page:  65 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=67
# 5000 Number of Records for this page
# Records saved:  335000
# Checking page:  66 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=68
# 5000 Number of Records for this page
# Records saved:  340000
# Checking page:  67 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=69
# 5000 Number of Records for this page
# Records saved:  345000
# Checking page:  68 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=70
# 5000 Number of Records for this page
# Records saved:  350000
# Checking page:  69 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=71
# 5000 Number of Records for this page
# Records saved:  355000
# Checking page:  70 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=72
# 5000 Number of Records for this page
# Records saved:  360000
# Checking page:  71 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=73
# 5000 Number of Records for this page
# Records saved:  365000
# Checking page:  72 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=74
# 5000 Number of Records for this page
# Records saved:  370000
# Checking page:  73 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=75
# 5000 Number of Records for this page
# Records saved:  375000
# Checking page:  74 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=76
# 5000 Number of Records for this page
# Records saved:  380000
# Checking page:  75 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=77
# 5000 Number of Records for this page
# Records saved:  385000
# Checking page:  76 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=78
# 5000 Number of Records for this page
# Records saved:  390000
# Checking page:  77 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=79
# 5000 Number of Records for this page
# Records saved:  395000
# Checking page:  78 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=80
# 5000 Number of Records for this page
# Records saved:  400000
# Checking page:  79 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=81
# 5000 Number of Records for this page
# Records saved:  405000
# Checking page:  80 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=82
# 5000 Number of Records for this page
# Records saved:  410000
# Checking page:  81 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=83
# 5000 Number of Records for this page
# Records saved:  415000
# Checking page:  82 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=84
# 5000 Number of Records for this page
# Records saved:  420000
# Checking page:  83 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=85
# 5000 Number of Records for this page
# Records saved:  425000
# Checking page:  84 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=86
# 5000 Number of Records for this page
# Records saved:  430000
# Checking page:  85 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=87
# 5000 Number of Records for this page
# Records saved:  435000
# Checking page:  86 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=88
# 5000 Number of Records for this page
# Records saved:  440000
# Checking page:  87 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=89
# 5000 Number of Records for this page
# Records saved:  445000
# Checking page:  88 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=90
# 5000 Number of Records for this page
# Records saved:  450000
# Checking page:  89 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=91
# 5000 Number of Records for this page
# Records saved:  455000
# Checking page:  90 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=92
# 5000 Number of Records for this page
# Records saved:  460000
# Checking page:  91 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=93
# 5000 Number of Records for this page
# Records saved:  465000
# Checking page:  92 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=94
# 5000 Number of Records for this page
# Records saved:  470000
# Checking page:  93 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=95
# 5000 Number of Records for this page
# Records saved:  475000
# Checking page:  94 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=96
# 5000 Number of Records for this page
# Records saved:  480000
# Checking page:  95 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=97
# 5000 Number of Records for this page
# Records saved:  485000
# Checking page:  96 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=98
# 5000 Number of Records for this page
# Records saved:  490000
# Checking page:  97 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=99
# 5000 Number of Records for this page
# Records saved:  495000
# Checking page:  98 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=100
# 5000 Number of Records for this page
# Records saved:  500000
# Checking page:  99 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=101
# 5000 Number of Records for this page
# Records saved:  505000
# Checking page:  100 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=102
# 5000 Number of Records for this page
# Records saved:  510000
# Checking page:  101 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=103
# 5000 Number of Records for this page
# Records saved:  515000
# Checking page:  102 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=104
# 5000 Number of Records for this page
# Records saved:  520000
# Checking page:  103 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=105
# 5000 Number of Records for this page
# Records saved:  525000
# Checking page:  104 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=106
# 5000 Number of Records for this page
# Records saved:  530000
# Checking page:  105 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=107
# 5000 Number of Records for this page
# Records saved:  535000
# Checking page:  106 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=108
# 5000 Number of Records for this page
# Records saved:  540000
# Checking page:  107 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=109
# 5000 Number of Records for this page
# Records saved:  545000
# Checking page:  108 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=110
# 5000 Number of Records for this page
# Records saved:  550000
# Checking page:  109 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=111
# 5000 Number of Records for this page
# Records saved:  555000
# Checking page:  110 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=112
# 5000 Number of Records for this page
# Records saved:  560000
# Checking page:  111 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=113
# 5000 Number of Records for this page
# Records saved:  565000
# Checking page:  112 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=114
# 5000 Number of Records for this page
# Records saved:  570000
# Checking page:  113 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=115
# 5000 Number of Records for this page
# Records saved:  575000
# Checking page:  114 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=116
# 5000 Number of Records for this page
# Records saved:  580000
# Checking page:  115 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=117
# 5000 Number of Records for this page
# Records saved:  585000
# Checking page:  116 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=118
# 5000 Number of Records for this page
# Records saved:  590000
# Checking page:  117 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=119
# 5000 Number of Records for this page
# Records saved:  595000
# Checking page:  118 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=120
# 5000 Number of Records for this page
# Records saved:  600000
# Checking page:  119 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=121
# 5000 Number of Records for this page
# Records saved:  605000
# Checking page:  120 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=122
# 5000 Number of Records for this page
# Records saved:  610000
# Checking page:  121 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=123
# 5000 Number of Records for this page
# Records saved:  615000
# Checking page:  122 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=124
# 5000 Number of Records for this page
# Records saved:  620000
# Checking page:  123 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=125
# 5000 Number of Records for this page
# Records saved:  625000
# Checking page:  124 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=126
# 5000 Number of Records for this page
# Records saved:  630000
# Checking page:  125 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=127
# 5000 Number of Records for this page
# Records saved:  635000
# Checking page:  126 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=128
# 5000 Number of Records for this page
# Records saved:  640000
# Checking page:  127 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=129
# 5000 Number of Records for this page
# Records saved:  645000
# Checking page:  128 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=130
# 5000 Number of Records for this page
# Records saved:  650000
# Checking page:  129 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=131
# 5000 Number of Records for this page
# Records saved:  655000
# Checking page:  130 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=132
# 5000 Number of Records for this page
# Records saved:  660000
# Checking page:  131 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=133
# 5000 Number of Records for this page
# Records saved:  665000
# Checking page:  132 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=134
# 5000 Number of Records for this page
# Records saved:  670000
# Checking page:  133 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=135
# 5000 Number of Records for this page
# Records saved:  675000
# Checking page:  134 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=136
# 5000 Number of Records for this page
# Records saved:  680000
# Checking page:  135 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=137
# 5000 Number of Records for this page
# Records saved:  685000
# Checking page:  136 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=138
# 5000 Number of Records for this page
# Records saved:  690000
# Checking page:  137 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=139
# 5000 Number of Records for this page
# Records saved:  695000
# Checking page:  138 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=140
# 5000 Number of Records for this page
# Records saved:  700000
# Checking page:  139 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=141
# 5000 Number of Records for this page
# Records saved:  705000
# Checking page:  140 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=142
# 5000 Number of Records for this page
# Records saved:  710000
# Checking page:  141 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=143
# 5000 Number of Records for this page
# Records saved:  715000
# Checking page:  142 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=144
# 5000 Number of Records for this page
# Records saved:  720000
# Checking page:  143 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=145
# 5000 Number of Records for this page
# Records saved:  725000
# Checking page:  144 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=146
# 5000 Number of Records for this page
# Records saved:  730000
# Checking page:  145 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=147
# 5000 Number of Records for this page
# Records saved:  735000
# Checking page:  146 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=148
# 5000 Number of Records for this page
# Records saved:  740000
# Checking page:  147 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=149
# 5000 Number of Records for this page
# Records saved:  745000
# Checking page:  148 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=150
# 5000 Number of Records for this page
# Records saved:  750000
# Checking page:  149 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=151
# 5000 Number of Records for this page
# Records saved:  755000
# Checking page:  150 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=152
# 5000 Number of Records for this page
# Records saved:  760000
# Checking page:  151 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=153
# 5000 Number of Records for this page
# Records saved:  765000
# Checking page:  152 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=154
# 5000 Number of Records for this page
# Records saved:  770000
# Checking page:  153 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=155
# 5000 Number of Records for this page
# Records saved:  775000
# Checking page:  154 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=156
# 5000 Number of Records for this page
# Records saved:  780000
# Checking page:  155 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=157
# 5000 Number of Records for this page
# Records saved:  785000
# Checking page:  156 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=158
# 5000 Number of Records for this page
# Records saved:  790000
# Checking page:  157 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=159
# 5000 Number of Records for this page
# Records saved:  795000
# Checking page:  158 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=160
# 5000 Number of Records for this page
# Records saved:  800000
# Checking page:  159 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=161
# 5000 Number of Records for this page
# Records saved:  805000
# Checking page:  160 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=162
# 5000 Number of Records for this page
# Records saved:  810000
# Checking page:  161 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=163
# 5000 Number of Records for this page
# Records saved:  815000
# Checking page:  162 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=164
# 5000 Number of Records for this page
# Records saved:  820000
# Checking page:  163 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=165
# 5000 Number of Records for this page
# Records saved:  825000
# Checking page:  164 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=166
# 5000 Number of Records for this page
# Records saved:  830000
# Checking page:  165 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=167
# 5000 Number of Records for this page
# Records saved:  835000
# Checking page:  166 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=168
# 5000 Number of Records for this page
# Records saved:  840000
# Checking page:  167 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=169
# 5000 Number of Records for this page
# Records saved:  845000
# Checking page:  168 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=170
# 5000 Number of Records for this page
# Records saved:  850000
# Checking page:  169 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=171
# 5000 Number of Records for this page
# Records saved:  855000
# Checking page:  170 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=172
# 5000 Number of Records for this page
# Records saved:  860000
# Checking page:  171 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=173
# 5000 Number of Records for this page
# Records saved:  865000
# Checking page:  172 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=174
# 5000 Number of Records for this page
# Records saved:  870000
# Checking page:  173 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=175
# 5000 Number of Records for this page
# Records saved:  875000
# Checking page:  174 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=176
# 5000 Number of Records for this page
# Records saved:  880000
# Checking page:  175 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=177
# 5000 Number of Records for this page
# Records saved:  885000
# Checking page:  176 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=178
# 5000 Number of Records for this page
# Records saved:  890000
# Checking page:  177 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=179
# 5000 Number of Records for this page
# Records saved:  895000
# Checking page:  178 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=180
# 5000 Number of Records for this page
# Records saved:  900000
# Checking page:  179 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=181
# 5000 Number of Records for this page
# Records saved:  905000
# Checking page:  180 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=182
# 5000 Number of Records for this page
# Records saved:  910000
# Checking page:  181 of  183
# Downloading  https://python.zgulde.net//api/v1/sales?page=183
# 3000 Number of Records for this page
# Records saved:  913000
# Shape of sales df:  (913000, 5)
#    item  sale_amount                      sale_date  sale_id  store
# 0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1

# %%
sales.to_csv('sales.csv', index = None)

# %% [markdown]
# 4. Save the data in your files to local csv files so that it will be faster to access in the future.

# %%
sales.to_csv('sales.csv',index=False)
stores.to_csv('stores.csv', index=False)
items.to_csv('items.csv', index=False)

# %% [markdown]
# 5.  Combine all data into one large dataframe

# %%
combined = sales.merge(items, how = 'left',
                       left_on = 'item', 
                       right_on = 'item_id').merge(stores, how = 'left',
                                                   left_on = 'store', 
                                                   right_on = 'store_id')
combined
# Out:
#         item  sale_amount                      sale_date  sale_id  store  \
# 0          1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1          1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2          1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3          1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4          1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...      ...          ...                            ...      ...    ...
# 912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
#        item_brand  item_id                                          item_name  \
# 0        Riceland        1                     Riceland American Jazmine Rice
# 1        Riceland        1                     Riceland American Jazmine Rice
# 2        Riceland        1                     Riceland American Jazmine Rice
# 3        Riceland        1                     Riceland American Jazmine Rice
# 4        Riceland        1                     Riceland American Jazmine Rice
# ...           ...      ...                                                ...
# 912995     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912996     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912997     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912998     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912999     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
#
#         item_price   item_upc12   item_upc14           store_address  \
# 0             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 1             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 2             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 3             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# 4             0.84  35200264013  35200264013  12125 Alamo Ranch Pkwy
# ...            ...          ...          ...                     ...
# 912995        5.20  47445919221  47445919221    8503 NW Military Hwy
# 912996        5.20  47445919221  47445919221    8503 NW Military Hwy
# 912997        5.20  47445919221  47445919221    8503 NW Military Hwy
# 912998        5.20  47445919221  47445919221    8503 NW Military Hwy
# 912999        5.20  47445919221  47445919221    8503 NW Military Hwy
#
#          store_city  store_id store_state store_zipcode
# 0       San Antonio         1          TX         78253
# 1       San Antonio         1          TX         78253
# 2       San Antonio         1          TX         78253
# 3       San Antonio         1          TX         78253
# 4       San Antonio         1          TX         78253
# ...             ...       ...         ...           ...
# 912995  San Antonio        10          TX         78231
# 912996  San Antonio        10          TX         78231
# 912997  San Antonio        10          TX         78231
# 912998  San Antonio        10          TX         78231
# 912999  San Antonio        10          TX         78231
#
# [913000 rows x 16 columns]

# %% [markdown]
# 6. Acquire the Open Power Systems Data for Germany

# %%
data = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')
data.to_csv('power_systems.csv', index=False)

# %%
data.shape
# Out:
# (4383, 5)

# %%
data
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]
